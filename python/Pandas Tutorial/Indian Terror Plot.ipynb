# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
events = pd.read_csv("globalterrorismdb_0616dist.csv", encoding="ISO-8859-1", low_memory=False)

events = events[events["country_txt"] == "India"]

events["city"]
# Out:
# 1185              New Delhi
# 2688             Samastipur
# 3780              New Delhi
# 5251                 Bombay
# 7261                Unknown
# 7266                 Imphal
# 8098                Unknown
# 8609                Unknown
# 8755                Unknown
# 8760                 Aizawl
# 8761                 Aizawl
# 8977                 Amapur
# 9037               Raisikah
# 9040               Champhai
# 9070                 Aizawl
# 9072             Jamshedpur
# 9081              New Delhi
# 9082              New Delhi
# 9090             Jamshedpur
# 9137                Chennai
# 9237                Unknown
# 9691                Unknown
# 9732                Unknown
# 9801                Unknown
# 9841                 Imphal
# 9887                Unknown
# 10407             Chiaplant
# 10414                Tindol
# 10522              Calcutta
# 10744             New Delhi
#                 ...
# 156156           Dariyakona
# 156176             Awapalli
# ...

# %%
country_cross = pd.crosstab(events.iyear, events.city)

country_cross.head(5)
# Out:
# city   Aankro  Aatpal  Abhapalli  Abhayapuri  Abhoynagar  Abohar  Aboi  \
# iyear
# 1972        0       0          0           0           0       0     0
# 1975        0       0          0           0           0       0     0
# 1976        0       0          0           0           0       0     0
# 1977        0       0          0           0           0       0     0
# 1979        0       0          0           0           0       0     0
#
# city   Achabal  Achanbigei  Acheli ...   guwahati  kangan  khargone  \
# iyear                              ...
# 1972         0           0       0 ...          0       0         0
# 1975         0           0       0 ...          0       0         0
# 1976         0           0       0 ...          0       0         0
# 1977         0           0       0 ...          0       0         0
# 1979         0           0       0 ...          0       0         0
#
# city   kokrajhar district  ludhiana  nalbari district  new delhi  runikhata  \
# ...

# %%
plt.figure(figsize=(30, 30))

for column in country_cross.columns:
    plt.plot(country_cross.index, country_cross[column])

plt.xlabel('Year')
plt.ylabel('Number of Attacks')
